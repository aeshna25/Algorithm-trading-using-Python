# %% [markdown]
# <a href="https://colab.research.google.com/github/aeshna25/Algorithm-trading-using-Python/blob/main/Algo_trading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ! pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
apple  = yf.download('AAPL', start ='2014-01-01', end ='2024-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-02   19.845715   19.893929   19.715000   19.754642   17.296652
# 2014-01-03   19.745001   19.775000   19.301071   19.320715   16.916727
# 2014-01-06   19.194643   19.528570   19.057142   19.426071   17.008966
# 2014-01-07   19.440001   19.498571   19.211430   19.287144   16.887327
# 2014-01-08   19.243214   19.484285   19.238930   19.409286   16.994268
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.353287
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.803986
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.903839
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.333298
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.284637
#
#                Volume
# Date
# 2014-01-02  234684800
# 2014-01-03  392467600
# 2014-01-06  412610800
# ...

# %%
ticker =['SPY','AAPL','KO']

# %%
stocks  = yf.download(ticker, start ='2014-01-01', end ='2024-01-01')
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks.head()
# Out:
# Price       Adj Close                             Close             \
# Ticker           AAPL         KO         SPY       AAPL         KO
# Date
# 2014-01-02  17.296652  29.140585  152.196289  19.754642  40.660000
# 2014-01-03  16.916727  28.997250  152.171295  19.320715  40.459999
# 2014-01-06  17.008966  28.861061  151.730331  19.426071  40.270000
# 2014-01-07  16.887327  28.947077  152.662247  19.287144  40.389999
# 2014-01-08  16.994268  28.624567  152.695541  19.409286  39.939999
#
# Price                        High                               Low  \
# Ticker             SPY       AAPL         KO         SPY       AAPL
# Date
# 2014-01-02  182.919998  19.893929  41.230000  184.070007  19.715000
# 2014-01-03  182.889999  19.775000  40.730000  183.600006  19.301071
# 2014-01-06  182.360001  19.528570  40.590000  183.559998  19.057142
# 2014-01-07  183.479996  19.498571  40.720001  183.789993  19.211430
# 2014-01-08  183.520004  19.484285  40.439999  183.830002  19.238930
#
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2014-01-02 to 2023-12-29
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2516 non-null   float64
#  1   (Adj Close, KO)    2516 non-null   float64
#  2   (Adj Close, SPY)   2516 non-null   float64
#  3   (Close, AAPL)      2516 non-null   float64
#  4   (Close, KO)        2516 non-null   float64
#  5   (Close, SPY)       2516 non-null   float64
#  6   (High, AAPL)       2516 non-null   float64
#  7   (High, KO)         2516 non-null   float64
#  8   (High, SPY)        2516 non-null   float64
#  9   (Low, AAPL)        2516 non-null   float64
#  10  (Low, KO)          2516 non-null   float64
#  11  (Low, SPY)         2516 non-null   float64
#  12  (Open, AAPL)       2516 non-null   float64
#  13  (Open, KO)         2516 non-null   float64
#  14  (Open, SPY)        2516 non-null   float64
# ...

# %%
# convert multi index to 1 tuple
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks.head()
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2014-01-02          17.296652        29.140585        152.196289
# 2014-01-03          16.916727        28.997250        152.171295
# 2014-01-06          17.008966        28.861061        151.730331
# 2014-01-07          16.887327        28.947077        152.662247
# 2014-01-08          16.994268        28.624567        152.695541
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2014-01-02      19.754642    40.660000    182.919998     19.893929
# 2014-01-03      19.320715    40.459999    182.889999     19.775000
# 2014-01-06      19.426071    40.270000    182.360001     19.528570
# 2014-01-07      19.287144    40.389999    183.479996     19.498571
# 2014-01-08      19.409286    39.939999    183.520004     19.484285
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# 2014-01-02   41.230000   184.070007    19.715000  40.509998  182.479996
# ...

# %%
stocks.describe()
# Out:
#        (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  (Close, AAPL)  \
# count        2516.000000      2516.000000       2516.000000    2516.000000
# mean           75.888208        41.971788        278.875778      77.920721
# std            56.658818        10.131391         96.878283      56.226768
# min            15.628377        26.589172        144.915939      17.849285
# 25%            27.197020        33.047224        183.617592      29.803750
# 50%            46.033031        39.041128        255.790627      48.107500
# 75%           132.483524        50.074202        377.521057     134.562496
# max           197.857529        61.839535        475.213501     198.110001
#
#        (Close, KO)  (Close, SPY)  (High, AAPL)   (High, KO)  (High, SPY)  \
# count  2516.000000   2516.000000   2516.000000  2516.000000  2516.000000
# mean     49.170334    300.164014     78.704468    49.500397   301.771498
# ...

# %%
close = stocks.loc[:,[('Close', 'AAPL'),('Close', 'KO'),('Close', 'SPY')]].copy()

# %%
close
# Out:
#             (Close, AAPL)  (Close, KO)  (Close, SPY)
# Date
# 2014-01-02      19.754642    40.660000    182.919998
# 2014-01-03      19.320715    40.459999    182.889999
# 2014-01-06      19.426071    40.270000    182.360001
# 2014-01-07      19.287144    40.389999    183.479996
# 2014-01-08      19.409286    39.939999    183.520004
# ...                   ...          ...           ...
# 2023-12-22     193.600006    58.320000    473.649994
# 2023-12-26     193.050003    58.560001    475.649994
# 2023-12-27     193.149994    58.709999    476.510010
# 2023-12-28     193.580002    58.750000    476.690002
# 2023-12-29     192.529999    58.930000    475.309998
#
# [2516 rows x 3 columns]

# %%
# %matplotlib inline

plt.style.use('seaborn')
# Out:
# <ipython-input-15-9574cfa13b6b>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
close.plot(figsize=(10,6), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# The starting point for all the tickers is different, so we will normalize it

# %%
close.iloc[0,0]
# Out:
# 19.754642486572266

# %%
close[('Close', 'AAPL')]
# Out:
# Date
# 2014-01-02     19.754642
# 2014-01-03     19.320715
# 2014-01-06     19.426071
# 2014-01-07     19.287144
# 2014-01-08     19.409286
#                  ...
# 2023-12-22    193.600006
# 2023-12-26    193.050003
# 2023-12-27    193.149994
# 2023-12-28    193.580002
# 2023-12-29    192.529999
# Name: (Close, AAPL), Length: 2516, dtype: float64

# %%
close[('Close', 'AAPL')].div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2014-01-02    100.000000
# 2014-01-03     97.803415
# 2014-01-06     98.336739
# 2014-01-07     97.633474
# 2014-01-08     98.251773
#                  ...
# 2023-12-22    980.022829
# 2023-12-26    977.238658
# 2023-12-27    977.744821
# 2023-12-28    979.921565
# 2023-12-29    974.606343
# Name: (Close, AAPL), Length: 2516, dtype: float64

# %%
close.iloc[0]
# Out:
# (Close, AAPL)     19.754642
# (Close, KO)       40.660000
# (Close, SPY)     182.919998
# Name: 2014-01-02 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#             (Close, AAPL)  (Close, KO)  (Close, SPY)
# Date
# 2014-01-02     100.000000   100.000000    100.000000
# 2014-01-03      97.803415    99.508114     99.983600
# 2014-01-06      98.336739    99.040828     99.693857
# 2014-01-07      97.633474    99.335956    100.306143
# 2014-01-08      98.251773    98.229215    100.328016
# ...                   ...          ...           ...
# 2023-12-22     980.022829   143.433350    258.938333
# 2023-12-26     977.238658   144.023614    260.031707
# 2023-12-27     977.744821   144.392522    260.501867
# 2023-12-28     979.921565   144.490901    260.600266
# 2023-12-29     974.606343   144.933597    259.845836
#
# [2516 rows x 3 columns]

# %%
norm_close =close.div(close.iloc[0]).mul(100)

# %%
norm_close.plot(figsize=(10,6), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# Now we can compare the performance of all companies and come to the conclusion that apple has performed better than both coco-cola and SPY
#
# Coco-cola performed the least

# %%
# returns of apple stock

aapl = close[('Close', 'AAPL')].to_frame(name='AAPL')
aapl.head()
# Out:
#                  AAPL
# Date
# 2014-01-02  19.754642
# 2014-01-03  19.320715
# 2014-01-06  19.426071
# 2014-01-07  19.287144
# 2014-01-08  19.409286

# %%
# increase or decrease from previous date
aapl.shift(1)
# Out:
#                   AAPL
# Date
# 2014-01-02         NaN
# 2014-01-03   19.754642
# 2014-01-06   19.320715
# 2014-01-07   19.426071
# 2014-01-08   19.287144
# ...                ...
# 2023-12-22  194.679993
# 2023-12-26  193.600006
# 2023-12-27  193.050003
# 2023-12-28  193.149994
# 2023-12-29  193.580002
#
# [2516 rows x 1 columns]

# %%
aapl['lag1'] = aapl.shift(1)

# %%
aapl.head()
# Out:
#                  AAPL       lag1
# Date
# 2014-01-02  19.754642        NaN
# 2014-01-03  19.320715  19.754642
# 2014-01-06  19.426071  19.320715
# 2014-01-07  19.287144  19.426071
# 2014-01-08  19.409286  19.287144

# %%
aapl['Diff']=aapl['AAPL'] - aapl['lag1'] # diff()

# %%
aapl.head()
# Out:
#                  AAPL       lag1      Diff
# Date
# 2014-01-02  19.754642        NaN       NaN
# 2014-01-03  19.320715  19.754642 -0.433928
# 2014-01-06  19.426071  19.320715  0.105356
# 2014-01-07  19.287144  19.426071 -0.138927
# 2014-01-08  19.409286  19.287144  0.122143

# %%
aapl['% change']=aapl['AAPL'].div(aapl['lag1']).sub(1).mul(100) # pct_change()

# %%
aapl.head()
# Out:
#                  AAPL       lag1      Diff  % change
# Date
# 2014-01-02  19.754642        NaN       NaN       NaN
# 2014-01-03  19.320715  19.754642 -0.433928 -2.196585
# 2014-01-06  19.426071  19.320715  0.105356  0.545302
# 2014-01-07  19.287144  19.426071 -0.138927 -0.715160
# 2014-01-08  19.409286  19.287144  0.122143  0.633286

# %%
del aapl['lag1']

# %%
del aapl['Diff']

# %%
aapl.head()
# Out:
#                  AAPL  % change
# Date
# 2014-01-02  19.754642       NaN
# 2014-01-03  19.320715 -2.196585
# 2014-01-06  19.426071  0.545302
# 2014-01-07  19.287144 -0.715160
# 2014-01-08  19.409286  0.633286

# %%
aapl= aapl.rename(columns ={'% change': 'Change'})

# %%
aapl.head()
# Out:
#                  AAPL    Change
# Date
# 2014-01-02  19.754642       NaN
# 2014-01-03  19.320715 -2.196585
# 2014-01-06  19.426071  0.545302
# 2014-01-07  19.287144 -0.715160
# 2014-01-08  19.409286  0.633286

# %%
aapl['AAPL'].resample('M').last() # gives last day closing for each month
# Out:
# Date
# 2014-01-31     17.878571
# 2014-02-28     18.794287
# 2014-03-31     19.169287
# 2014-04-30     21.074642
# 2014-05-31     22.607143
#                  ...
# 2023-08-31    187.869995
# 2023-09-30    171.210007
# 2023-10-31    170.770004
# 2023-11-30    189.949997
# 2023-12-31    192.529999
# Freq: M, Name: AAPL, Length: 120, dtype: float64

# %%
aapl['AAPL'].resample('BM').last() # gives last business day closing for each month
# Out:
# Date
# 2014-01-31     17.878571
# 2014-02-28     18.794287
# 2014-03-31     19.169287
# 2014-04-30     21.074642
# 2014-05-30     22.607143
#                  ...
# 2023-08-31    187.869995
# 2023-09-29    171.210007
# 2023-10-31    170.770004
# 2023-11-30    189.949997
# 2023-12-29    192.529999
# Freq: BM, Name: AAPL, Length: 120, dtype: float64

# %%
#monthly change
aapl['AAPL'].resample('BM').last().pct_change(1).mul(100)
# Out:
# Date
# 2014-01-31          NaN
# 2014-02-28     5.121865
# 2014-03-31     1.995287
# 2014-04-30     9.939626
# 2014-05-30     7.271778
#                 ...
# 2023-08-31    -4.367525
# 2023-09-29    -8.867828
# 2023-10-31    -0.256996
# 2023-11-30    11.231476
# 2023-12-29     1.358253
# Freq: BM, Name: AAPL, Length: 120, dtype: float64

# %%
## calculate mean return and standard deviation

ret = aapl['AAPL'].pct_change().dropna()

# %%
ret
# Out:
# Date
# 2014-01-03   -0.021966
# 2014-01-06    0.005453
# 2014-01-07   -0.007152
# 2014-01-08    0.006333
# 2014-01-09   -0.012770
#                 ...
# 2023-12-22   -0.005547
# 2023-12-26   -0.002841
# 2023-12-27    0.000518
# 2023-12-28    0.002226
# 2023-12-29   -0.005424
# Name: AAPL, Length: 2515, dtype: float64

# %%
# histogram
ret.plot(kind ='hist', figsize=(10,6), bins=100)
plt.show()

# %% [markdown]
# The range of close varies from -5 to 5 percent change

# %%
daily_mean  =ret.mean()
daily_mean
# Out:
# 0.0010657190793902647

# %%
var_daily  =ret.var()
var_daily
# Out:
# 0.0003199406876373178

# %%
std_daily = np.sqrt(var_daily) #ret.std()
std_daily
# Out:
# 0.017886885912235192

# %%
annual_mean_ret = daily_mean*252
annual_mean_ret
# Out:
# 0.2685612080063467

# %% [markdown]
# We are getting a annual mean return of apple shares, which is around 27%

# %%
annual_var_ret = var_daily*252
annual_var_ret
# Out:
# 0.08062505328460409

# %%
annual_std_ret = np.sqrt(annual_var_ret)
annual_std_ret
# Out:
# 0.2839455111189541

# %% [markdown]
# Try with more tickers

# %%
ticker =['SPY','AAPL','KO','IBM','DIS','MSFT']

# %%
stocks  = yf.download(ticker, start ='2014-01-01', end ='2024-01-01')
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
close = stocks.loc[:,[('Close', 'AAPL'),('Close', 'KO'),('Close', 'SPY'),('Close', 'IBM'),('Close', 'DIS'),('Close', 'MSFT')]].copy()

# %%
norm_close =close.div(close.iloc[0]).mul(100)

# %%
norm_close.plot(figsize=(10,6), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ## Risk to Reward Ratio
#
#
# Calculate percentage change for all of these

# %%
ret= close.pct_change().dropna()
ret.head()
# Out:
# Price          Close
# Ticker          AAPL        KO       SPY       IBM       DIS      MSFT
# Date
# 2014-01-03 -0.021966 -0.004919 -0.000164  0.005983 -0.002098 -0.006728
# 2014-01-06  0.005453 -0.004696 -0.002898 -0.003429 -0.003810 -0.021132
# 2014-01-07 -0.007152  0.002980  0.006142  0.019946  0.006858  0.007750
# 2014-01-08  0.006333 -0.011141  0.000218 -0.009172 -0.014671 -0.017852
# 2014-01-09 -0.012770 -0.005258  0.000654 -0.003139 -0.004254 -0.006432

# %%
summary = ret.describe().T.loc[:, ['mean', 'std']]

# %%
summary['mean'] = summary['mean']*252
summary['std'] = summary['std']*np.sqrt(252)

# %%
summary
# Out:
#                   mean       std
# Price Ticker
# Close AAPL    0.268561  0.283946
#       KO      0.053507  0.180117
#       SPY     0.111256  0.176022
#       IBM     0.019452  0.234213
#       DIS     0.053830  0.271999
#       MSFT    0.268653  0.270872

# %%
summary.plot.scatter(x ='std',y='mean', figsize=(10,6), s=50, alpha=0.3, fontsize=15)
for i in summary.index:
    plt.annotate(i, (summary.loc[i, 'std']+0.002, summary.loc[i, 'mean']+0.002))
plt.xlabel('Standard Deviation', fontsize=15)
plt.ylabel('Mean Return', fontsize=15)
plt.title('Risk to Reward', fontsize=20)
plt.show()

# %% [markdown]
# Apple and MSFT have good returns but they come at high risk
#
# Disney, IBM have low returns at medium to high risk
#
# Coco-cola has low return at low risk
#
# SPY are most consistent with medium return at very low risk

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
# Price          Close
# Ticker          AAPL        KO       SPY       IBM       DIS      MSFT
# Date
# 2014-01-03 -0.021966 -0.004919 -0.000164  0.005983 -0.002098 -0.006728
# 2014-01-06  0.005453 -0.004696 -0.002898 -0.003429 -0.003810 -0.021132
# 2014-01-07 -0.007152  0.002980  0.006142  0.019946  0.006858  0.007750
# 2014-01-08  0.006333 -0.011141  0.000218 -0.009172 -0.014671 -0.017852
# 2014-01-09 -0.012770 -0.005258  0.000654 -0.003139 -0.004254 -0.006432
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22 -0.005547  0.005691  0.002010  0.008459 -0.010867  0.002784
# 2023-12-26 -0.002841  0.004115  0.004223  0.006599 -0.000769  0.000214
# 2023-12-27  0.000518  0.002561  0.001808  0.001532 -0.006267 -0.001575
# 2023-12-28  0.002226  0.000681  0.000378  0.001774  0.000221  0.003235
# 2023-12-29 -0.005424  0.003064 -0.002895 -0.001221 -0.001217  0.002025
#
# [2515 rows x 6 columns]

# %%
ret.cov()
# Out:
# Price            Close
# Ticker            AAPL        KO       SPY       IBM       DIS      MSFT
# Price Ticker
# Close AAPL    0.000320  0.000073  0.000148  0.000108  0.000133  0.000204
#       KO      0.000073  0.000129  0.000075  0.000079  0.000079  0.000079
#       SPY     0.000148  0.000075  0.000123  0.000104  0.000126  0.000149
#       IBM     0.000108  0.000079  0.000104  0.000218  0.000104  0.000114
#       DIS     0.000133  0.000079  0.000126  0.000104  0.000294  0.000135
#       MSFT    0.000204  0.000079  0.000149  0.000114  0.000135  0.000291

# %%
ret.corr()
# Out:
# Price            Close
# Ticker            AAPL        KO       SPY       IBM       DIS      MSFT
# Price Ticker
# Close AAPL    1.000000  0.361822  0.743929  0.407792  0.433142  0.669748
#       KO      0.361822  1.000000  0.597736  0.472330  0.408494  0.406485
#       SPY     0.743929  0.597736  1.000000  0.636581  0.661625  0.786317
#       IBM     0.407792  0.472330  0.636581  1.000000  0.412602  0.450886
#       DIS     0.433142  0.408494  0.661625  0.412602  1.000000  0.460965
#       MSFT    0.669748  0.406485  0.786317  0.450886  0.460965  1.000000

# %%
import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(ret.corr(), annot=True)
plt.show()

# %% [markdown]
# All tickers have good correlation with SPY
#
# MSFT and APPLE have good correlation

# %% [markdown]
# Adding 20 tickers and comparing
#
# 1. Closing price
# 2. Risk to reward ratio
# 3. Correlation
# 5. Top 5 companies to invest

# %%
ticker =['SPY','AAPL','KO','IBM','DIS','MSFT','JPM','VOD','T','WFC','PEP','UNH','QCOM','DELL','DB','MET','FDX','HON','K','WIT']
stocks  = yf.download(ticker, start ='2014-01-01', end ='2024-01-01')
# Out:
# [*********************100%%**********************]  20 of 20 completed

# %%
close = stocks.loc[:,[('Close', 'AAPL'),('Close', 'KO'),('Close', 'SPY'),('Close', 'IBM'),('Close', 'DIS'),('Close', 'MSFT'),('Close', 'JPM'),('Close', 'VOD'),('Close', 'T'),('Close', 'WFC'),('Close', 'PEP'),('Close', 'UNH'),('Close', 'QCOM'),('Close', 'DELL'),('Close', 'DB'),('Close', 'MET'),('Close', 'FDX'),('Close', 'HON'),('Close', 'K'),('Close', 'WIT')]].copy()

# %%
norm_close =close.div(close.iloc[0]).mul(100)

# %%
norm_close.head()
# Out:
# Price            Close                                                  \
# Ticker            AAPL          KO         SPY         IBM         DIS
# Date
# 2014-01-02  100.000000  100.000000  100.000000  100.000000  100.000000
# 2014-01-03   97.803415   99.508114   99.983600  100.598287   99.790224
# 2014-01-06   98.336739   99.040828   99.693857  100.253325   99.409995
# 2014-01-07   97.633474   99.335956  100.306143  102.253002  100.091779
# 2014-01-08   98.251773   98.229215  100.328016  101.315146   98.623318
#
# Price                                                                   \
# Ticker            MSFT         JPM         VOD           T         WFC
# Date
# 2014-01-02  100.000000  100.000000  100.000000  100.000000  100.000000
# 2014-01-03   99.327234  100.773064   98.816575   99.570817  100.710795
# 2014-01-06   97.228206  101.357157   99.665549  100.028613  100.888489
# 2014-01-07   97.981701  100.188972   99.845642  100.000000  100.844072
# ...

# %%
norm_close.describe()
# Out:
# Price         Close                                                      \
# Ticker         AAPL           KO          SPY          IBM          DIS
# count   2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# mean     394.442576   120.930482   164.095789    79.296619   150.060263
# std      284.625593    18.497865    49.051229     9.957370    35.438321
# min       90.354888    91.244463    95.216488    51.080687    91.766095
# 25%      150.869600   104.992619   116.157337    72.698485   126.668421
# 50%      243.525035   114.252337   152.695167    78.000861   140.618860
# 75%      681.168977   135.323414   213.057626    84.467470   163.894727
# max     1002.852877   162.838169   261.157881   106.597316   264.730579
#
# Price                                                                    \
# Ticker         MSFT          JPM          VOD            T          WFC
# count   2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# ...

# %%
norm_close.plot(figsize=(12,15), fontsize=12)
for col in norm_close.columns:
    plt.annotate(col,xy=(plt.xticks()[0][-1]+0.7, norm_close[col].iloc[-1]))
plt.legend(fontsize=12,loc='upper left')
plt.show()

# %% [markdown]
# Top 3 stocks with highest closing price are APPLE, MSFT and United Health group Incorporated
#
# Bottom 3 stocks with lowest closing price are VODAFONE, DEUTSCHE BANK, AT & T

# %%
# RISK TO REWARD

ret = close.pct_change().dropna()
summary =ret.describe().T.loc[:, ['mean', 'std']]
summary['mean'] = summary['mean']*252
summary['std'] = summary['std']*np.sqrt(252)
summary
# Out:
#                   mean       std
# Price Ticker
# Close AAPL    0.309391  0.295889
#       KO      0.057856  0.190854
#       SPY     0.123415  0.187591
#       IBM     0.038944  0.245217
#       DIS     0.033324  0.293339
#       MSFT    0.294341  0.279739
#       JPM     0.169324  0.284623
#       VOD    -0.133400  0.284877
#       T      -0.055553  0.246677
#       WFC     0.058152  0.335776
#       PEP     0.080463  0.197281
#       UNH     0.214076  0.266780
#       QCOM    0.185561  0.378391
#       DELL    0.315435  0.357960
#       DB      0.081284  0.413596
#       MET     0.132445  0.314522
#       FDX     0.114187  0.336191
#       HON     0.116212  0.240637
#       K      -0.020112  0.220200
#       WIT     0.042258  0.284195

# %%
summary.plot.scatter(x ='std',y='mean', figsize=(10,6), s=50, alpha=0.3, fontsize=15)
for i in summary.index:
    plt.annotate(i, (summary.loc[i, 'std']+0.002, summary.loc[i, 'mean']+0.002))
plt.xlabel('Standard Deviation', fontsize=15)
plt.ylabel('Mean Return', fontsize=15)
plt.title('Risk to Reward', fontsize=20)
plt.show()

# %% [markdown]
# Dell , Apple and MSFT have a good return but comes with high risk
#
# DEUTSCHE BANK, Vodafone, Wells fargo, Disney, wipro have low return but high risk
#
# AT & T , Coco-cola, Kellogg, IBM, Pepsi have low return and low risk
#
# SPY, Honeywell, United health group, J P Morgan have high return for low risk

# %% [markdown]
# Top 5 companies to invest in long term
#
# 1. SPY : High reward low risk
# 2. MSFT : High reward medium risk
# 3. DELL : High reward high risk
# 4. UNH : High reward medium risk
# 5. APPL : High reward high risk (consistency)

# %%
import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(ret.corr(), annot=True)
plt.show()

# %% [markdown]
# Companies belonging to same domain have high correlation. E.g.: (Coco-cola, Pepsi), (Apple, Qcom, Msft), (DB, JPM, WFC), (Metlife, JPM, WFC, DB)

# %% [markdown]
# # Simple and Log returns
#  [When to use which](https://medium.com/@manojkotary/simple-returns-vs-log-returns-a-comprehensive-comparative-analysis-for-financial-analysis-702403693bad)

# %%
SPY  = yf.download('SPY')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy =SPY[['Close']]

# %%
spy.head()
# Out:
#                Close
# Date
# 1993-01-29  43.93750
# 1993-02-01  44.25000
# 1993-02-02  44.34375
# 1993-02-03  44.81250
# 1993-02-04  45.00000

# %%
spy.plot(figsize=(10,6))
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
# calculate moving average
# we would need rolling function : calculates past experience

spy_roll = spy.rolling(window=10)

# %%
spy_roll=spy_roll.mean()
spy_roll
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-06-13  534.331995
# 2024-06-14  535.872998
# 2024-06-17  537.802997
# 2024-06-18  539.812994
# 2024-06-20  541.045996
#
# [7904 rows x 1 columns]

# %%
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.iloc[0:10].mean()
# Out:
# Close    44.659375
# dtype: float64

# %%
spy['SMA50'] = spy.rolling(window=50, min_periods=50).mean()
# Out:
# <ipython-input-80-8de3d80fcb46>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['SMA50'] = spy.rolling(window=50, min_periods=50).mean()

# %%
spy['SMA200'] = spy['Close'].rolling(window=200, min_periods=200).mean()
# Out:
# <ipython-input-81-ff859a01daa6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy['SMA200'] = spy['Close'].rolling(window=200, min_periods=200).mean()

# %%
spy.plot(figsize=(10,6))
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %% [markdown]
# Example 2 : Dell

# %%
DELL  = yf.download('DELL')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dell = DELL[['Close']]

# %%
dell.plot(figsize=(10,6))
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
dell['SMA50'] = dell.rolling(window=50, min_periods=50).mean()
dell['SMA200'] = dell.Close.rolling(window=200, min_periods=200).mean()
# Out:
# <ipython-input-86-6477171d1622>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dell['SMA50'] = dell.rolling(window=50, min_periods=50).mean()
# <ipython-input-86-6477171d1622>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dell['SMA200'] = dell.Close.rolling(window=200, min_periods=200).mean()

# %%
dell.plot(figsize=(10,6))
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
HP  = yf.download('HPQ')

hp = HP[['Close']]

hp['SMA50'] = hp.rolling(window=50, min_periods=50).mean()
hp['SMA200'] = hp.Close.rolling(window=200, min_periods=200).mean()

hp.plot(figsize=(10,6))
plt.legend(loc='upper left',fontsize=15)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <ipython-input-88-521de1086ea0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hp['SMA50'] = hp.rolling(window=50, min_periods=50).mean()
# <ipython-input-88-521de1086ea0>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hp['SMA200'] = hp.Close.rolling(window=200, min_periods=200).mean()

# %% [markdown]
# Log returns

# %%
hp['EMA100'] = hp.Close.ewm(span=200, min_periods=200).mean()

hp.plot(figsize=(10,6))
plt.legend(loc='upper left',fontsize=15)
plt.show()
# Out:
# <ipython-input-89-fa660a1c4040>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hp['EMA100'] = hp.Close.ewm(span=200, min_periods=200).mean()

# %% [markdown]
# ### MISC

# %%
hp['Day'] = hp.index.day_name()
hp['Quarter'] = hp.index.quarter
hp.head()
# Out:
# <ipython-input-90-c2cecab0c844>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hp['Day'] = hp.index.day_name()
#                Close  SMA50  SMA200  EMA100        Day  Quarter
# Date
# 1962-01-02  0.124177    NaN     NaN     NaN    Tuesday        1
# 1962-01-03  0.122846    NaN     NaN     NaN  Wednesday        1
# 1962-01-04  0.120185    NaN     NaN     NaN   Thursday        1
# 1962-01-05  0.117525    NaN     NaN     NaN     Friday        1
# 1962-01-08  0.119299    NaN     NaN     NaN     Monday        1

# %% [markdown]
# One thing to notice here is sat and sun are missing , since the market is close that day, to make the data uniform without skipping any day data, we can do the below steps

# %%
HP  = yf.download('HPQ')

all_days = pd.date_range(start=HP.index.min(), end=HP.index.max())
all_days
# Out:
# [*********************100%%**********************]  1 of 1 completed
# DatetimeIndex(['1962-01-02', '1962-01-03', '1962-01-04', '1962-01-05',
#                '1962-01-06', '1962-01-07', '1962-01-08', '1962-01-09',
#                '1962-01-10', '1962-01-11',
#                ...
#                '2024-06-11', '2024-06-12', '2024-06-13', '2024-06-14',
#                '2024-06-15', '2024-06-16', '2024-06-17', '2024-06-18',
#                '2024-06-19', '2024-06-20'],
#               dtype='datetime64[ns]', length=22816, freq='D')

# %%
HP['Day'] = HP.index.day_name()
HP['Quarter'] = HP.index.quarter

# %%
HP = HP.reindex(all_days)
HP.head(10)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# 1962-01-02  0.131273  0.131273  0.124177  0.124177   0.042009  2480333.0
# 1962-01-03  0.124177  0.124177  0.121516  0.122846   0.041559   507341.0
# 1962-01-04  0.122846  0.126838  0.117968  0.120185   0.040659   845568.0
# 1962-01-05  0.119742  0.119742  0.117525  0.117525   0.039759   338227.0
# 1962-01-06       NaN       NaN       NaN       NaN        NaN        NaN
# 1962-01-07       NaN       NaN       NaN       NaN        NaN        NaN
# 1962-01-08  0.117525  0.119299  0.115307  0.119299   0.040359   873754.0
# 1962-01-09  0.119299  0.124177  0.117968  0.121072   0.040959   930125.0
# 1962-01-10  0.121072  0.121959  0.119299  0.121959   0.041259   450970.0
# 1962-01-11  0.121959  0.122403  0.120629  0.121516   0.041109   422784.0
#
#                   Day  Quarter
# 1962-01-02    Tuesday      1.0
# 1962-01-03  Wednesday      1.0
# 1962-01-04   Thursday      1.0
# 1962-01-05     Friday      1.0
# ...

# %% [markdown]
# Now instead of keeping Sat and Sun records as null, we can fill them with records of Friday (ffill) or Monday (bfill)

# %%
HP.fillna(method='ffill').iloc[3:7]
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# 1962-01-05  0.119742  0.119742  0.117525  0.117525   0.039759  338227.0
# 1962-01-06  0.119742  0.119742  0.117525  0.117525   0.039759  338227.0
# 1962-01-07  0.119742  0.119742  0.117525  0.117525   0.039759  338227.0
# 1962-01-08  0.117525  0.119299  0.115307  0.119299   0.040359  873754.0
#
#                Day  Quarter
# 1962-01-05  Friday      1.0
# 1962-01-06  Friday      1.0
# 1962-01-07  Friday      1.0
# 1962-01-08  Monday      1.0

# %%
HP.fillna(method='bfill').iloc[3:7]
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# 1962-01-05  0.119742  0.119742  0.117525  0.117525   0.039759  338227.0
# 1962-01-06  0.117525  0.119299  0.115307  0.119299   0.040359  873754.0
# 1962-01-07  0.117525  0.119299  0.115307  0.119299   0.040359  873754.0
# 1962-01-08  0.117525  0.119299  0.115307  0.119299   0.040359  873754.0
#
#                Day  Quarter
# 1962-01-05  Friday      1.0
# 1962-01-06  Monday      1.0
# 1962-01-07  Monday      1.0
# 1962-01-08  Monday      1.0

# %% [markdown]
# To download data for a company on week interval

# %%
HP = yf.download('HPQ',  interval='1wk')
HP.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 1962-01-01  0.131273  0.131273  0.117525  0.117525   0.039759  4171469
# 1962-01-08  0.117525  0.124177  0.115307  0.120629   0.040809  3213159
# 1962-01-15  0.120629  0.124177  0.115751  0.123290   0.041709  2818560
# 1962-01-22  0.123290  0.127725  0.118855  0.120629   0.040809  3917797
# 1962-01-29  0.119742  0.122846  0.117525  0.119299   0.040359  1634764

# %% [markdown]
# # Cummalative  returns and Dropdowns etc..

# %%
apple = yf.download('AAPL')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple = apple.Close.to_frame()

# %%
apple['d_returns'] = np.log(apple.div(apple.shift(1)))

# %%
apple = apple.dropna()

# %%
# sum of the returns
apple['d_returns'].sum()
# Out:
# 7.398592533604456

# %%
# what if we invested $1 on the first day, what will be the amount today
np.exp(apple['d_returns'].sum())
# Out:
# 1633.6834565383276

# %%
# cummalative returns
apple['cummareturns'] = apple['d_returns'].cumsum().apply(np.exp)  # it should give the same result as above on the last cell

# %%
apple
# Out:
#                  Close  d_returns  cummareturns
# Date
# 1980-12-15    0.121652  -0.053581      0.947829
# 1980-12-16    0.112723  -0.076231      0.878261
# 1980-12-17    0.115513   0.024450      0.899998
# 1980-12-18    0.118862   0.028580      0.926092
# 1980-12-19    0.126116   0.059239      0.982610
# ...                ...        ...           ...
# 2024-06-13  214.240005   0.005476   1669.211966
# 2024-06-14  212.490005  -0.008202   1655.577159
# 2024-06-17  216.669998   0.019480   1688.144811
# 2024-06-18  214.289993  -0.011045   1669.601436
# 2024-06-20  209.679993  -0.021748   1633.683457
#
# [10970 rows x 3 columns]

# %%
apple['cummareturns'].plot(figsize=(10,6), title ='Buy and hold : APPLE')
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %% [markdown]
# 1 Dollor invested in 1980, should return you around 1700 Dollor in 2024

# %%
annual_avg_return= apple['d_returns'].mean()*252
annual_avg_return
# Out:
# 0.16995855227605497

# %%
annual_std= apple['d_returns'].std()*np.sqrt(252)
annual_std
# Out:
# 0.4498586182771653

# %%
# how to calculate drawdowns
apple['cummax'] = apple['cummareturns'].cummax()
apple
# Out:
#                  Close  d_returns  cummareturns       cummax
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829
# 1980-12-17    0.115513   0.024450      0.899998     0.947829
# 1980-12-18    0.118862   0.028580      0.926092     0.947829
# 1980-12-19    0.126116   0.059239      0.982610     0.982610
# ...                ...        ...           ...          ...
# 2024-06-13  214.240005   0.005476   1669.211966  1669.211966
# 2024-06-14  212.490005  -0.008202   1655.577159  1669.211966
# 2024-06-17  216.669998   0.019480   1688.144811  1688.144811
# 2024-06-18  214.289993  -0.011045   1669.601436  1688.144811
# 2024-06-20  209.679993  -0.021748   1633.683457  1688.144811
#
# [10970 rows x 4 columns]

# %%
apple[['cummareturns','cummax']].plot(figsize=(10,6), title ='Buy and hold + Cummax: APPLE')
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
apple['drowdown'] =apple['cummax'] - apple['cummareturns']
apple
# Out:
#                  Close  d_returns  cummareturns       cummax   drowdown
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610   0.000000
# ...                ...        ...           ...          ...        ...
# 2024-06-13  214.240005   0.005476   1669.211966  1669.211966   0.000000
# 2024-06-14  212.490005  -0.008202   1655.577159  1669.211966  13.634806
# 2024-06-17  216.669998   0.019480   1688.144811  1688.144811   0.000000
# 2024-06-18  214.289993  -0.011045   1669.601436  1688.144811  18.543374
# 2024-06-20  209.679993  -0.021748   1633.683457  1688.144811  54.461354
#
# [10970 rows x 5 columns]

# %%
apple['drowdown'].max()
# Out:
# 444.02718404402026

# %%
apple['drowdown'].idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[apple['drowdown'].idxmax()]
# Out:
# Close            125.019997
# d_returns         -0.010661
# cummareturns     974.070524
# cummax          1418.097708
# drowdown         444.027184
# Name: 2023-01-05 00:00:00, dtype: float64

# %%
apple.loc[apple.index <= '2023-01-05']
# Out:
#                  Close  d_returns  cummareturns       cummax    drowdown
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2022-12-29  129.610001   0.027931   1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466   1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122    974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261    984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661    974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple['drawdown%'] = (apple['cummax'] - apple['cummareturns']) / apple['cummax']
apple
# Out:
#                  Close  d_returns  cummareturns       cummax   drowdown  \
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610   0.000000
# ...                ...        ...           ...          ...        ...
# 2024-06-13  214.240005   0.005476   1669.211966  1669.211966   0.000000
# 2024-06-14  212.490005  -0.008202   1655.577159  1669.211966  13.634806
# 2024-06-17  216.669998   0.019480   1688.144811  1688.144811   0.000000
# 2024-06-18  214.289993  -0.011045   1669.601436  1688.144811  18.543374
# 2024-06-20  209.679993  -0.021748   1633.683457  1688.144811  54.461354
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# ...

# %%
apple['drawdown%'].max()
# Out:
# 0.82216567924191

# %%
apple['drawdown%'].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[apple.index <= '1997-12-23']
# Out:
#                Close  d_returns  cummareturns    cummax  drowdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581      0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231      0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450      0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580      0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239      0.982610  0.982610  0.000000   0.000000
# ...              ...        ...           ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549      0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008      0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090      0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778      0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580      0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# The drawdown is different from drawdown%

# %% [markdown]
# ## SMA Strategy

# %%
data = apple.loc[apple.index >= '1991-01-01'][['Close']]
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2024-06-13  214.240005
# 2024-06-14  212.490005
# 2024-06-17  216.669998
# 2024-06-18  214.289993
# 2024-06-20  209.679993
#
# [8430 rows x 1 columns]

# %%
SMA_s=50
SMA_l =200

data['SMA_s'] = data['Close'].rolling(window=SMA_s, min_periods=SMA_s).mean()
data['SMA_l'] = data['Close'].rolling(window=SMA_l, min_periods=SMA_l).mean()
data
# Out:
#                  Close       SMA_s      SMA_l
# Date
# 1991-01-02    0.388393         NaN        NaN
# 1991-01-03    0.383929         NaN        NaN
# 1991-01-04    0.386161         NaN        NaN
# 1991-01-07    0.386161         NaN        NaN
# 1991-01-08    0.386161         NaN        NaN
# ...                ...         ...        ...
# 2024-06-13  214.240005  182.485400  182.28240
# 2024-06-14  212.490005  183.358800  182.42425
# 2024-06-17  216.669998  184.300600  182.56935
# 2024-06-18  214.289993  185.217400  182.70145
# 2024-06-20  209.679993  186.017599  182.80255
#
# [8430 rows x 3 columns]

# %%
data.plot(figsize=(10,6), title = "AAPL - SMA{} | SMA{}".format(SMA_s, SMA_l))
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
data.loc['2020'].plot(figsize=(10,6), title = "AAPL - SMA{} | SMA{}".format(SMA_s, SMA_l))
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
data.loc['2019'].plot(figsize=(10,6), title = "AAPL - SMA{} | SMA{}".format(SMA_s, SMA_l))
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
data = data.dropna()
data
# Out:
#                  Close       SMA_s       SMA_l
# Date
# 1991-10-15    0.468750    0.453772    0.470659
# 1991-10-16    0.477679    0.454487    0.471105
# 1991-10-17    0.467634    0.454844    0.471523
# 1991-10-18    0.491071    0.455647    0.472048
# 1991-10-21    0.488839    0.456362    0.472561
# ...                ...         ...         ...
# 2024-06-13  214.240005  182.485400  182.282400
# 2024-06-14  212.490005  183.358800  182.424250
# 2024-06-17  216.669998  184.300600  182.569350
# 2024-06-18  214.289993  185.217400  182.701450
# 2024-06-20  209.679993  186.017599  182.802550
#
# [8231 rows x 3 columns]

# %%
# sma_s > sma_l : long(1) else short(-1)

data['Position'] = np.where(data['SMA_s'] > data['SMA_l'], 1, -1)
data
# Out:
# <ipython-input-207-02a5b3a718f1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Position'] = np.where(data['SMA_s'] > data['SMA_l'], 1, -1)
#                  Close       SMA_s       SMA_l  Position
# Date
# 1991-10-15    0.468750    0.453772    0.470659        -1
# 1991-10-16    0.477679    0.454487    0.471105        -1
# 1991-10-17    0.467634    0.454844    0.471523        -1
# 1991-10-18    0.491071    0.455647    0.472048        -1
# 1991-10-21    0.488839    0.456362    0.472561        -1
# ...                ...         ...         ...       ...
# 2024-06-13  214.240005  182.485400  182.282400         1
# 2024-06-14  212.490005  183.358800  182.424250         1
# 2024-06-17  216.669998  184.300600  182.569350         1
# ...

# %%
data.loc['2019',["SMA_s","SMA_l","Position"]].plot(figsize=(10,6), title = "AAPL - SMA{} | SMA{}".format(SMA_s, SMA_l), secondary_y = "Position")
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
data['returnsbh'] = np.log(data['Close'].div(data['Close'].shift(1))) # buy and hold
data['strategy'] = data['Position'].shift(1) * data['returnsbh']
data
# Out:
# <ipython-input-209-a53142319c1f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returnsbh'] = np.log(data['Close'].div(data['Close'].shift(1))) # buy and hold
# <ipython-input-209-a53142319c1f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['strategy'] = data['Position'].shift(1) * data['returnsbh']
#                  Close       SMA_s       SMA_l  Position  returnsbh  strategy
# Date
# 1991-10-15    0.468750    0.453772    0.470659        -1        NaN       NaN
# ...

# %%
data= data.dropna()
data.head()
# Out:
#                Close     SMA_s     SMA_l  Position  returnsbh  strategy
# Date
# 1991-10-16  0.477679  0.454487  0.471105        -1   0.018869 -0.018869
# 1991-10-17  0.467634  0.454844  0.471523        -1  -0.021253  0.021253
# 1991-10-18  0.491071  0.455647  0.472048        -1   0.048903 -0.048903
# 1991-10-21  0.488839  0.456362  0.472561        -1  -0.004555  0.004555
# 1991-10-22  0.486607  0.456853  0.473064        -1  -0.004576  0.004576

# %%
data[['returnsbh','strategy']].sum()
# Out:
# returnsbh    6.103268
# strategy     2.733864
# dtype: float64

# %% [markdown]
# Buy and hold performs better

# %%
data[['returnsbh','strategy']].sum().apply(np.exp)
# Out:
# returnsbh    447.317318
# strategy      15.392245
# dtype: float64

# %% [markdown]
# dollor 1 investment will yeild dollar 447 using buy and hold and yeilds dollor 7 with strategy

# %%
data[['returnsbh','strategy']].std()*np.sqrt(252) #annual std
# Out:
# returnsbh    0.433443
# strategy     0.433571
# dtype: float64

# %% [markdown]
# Both have similar variance

# %% [markdown]
# ## Strategy adjusted with long bias

# %%
data['Position2'] = np.where(data['SMA_s'] > data['SMA_l'], 1, 0)
data
# Out:
# <ipython-input-214-cffd82ef126a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Position2'] = np.where(data['SMA_s'] > data['SMA_l'], 1, 0)
#                  Close       SMA_s       SMA_l  Position  returnsbh  strategy  \
# Date
# 1991-10-16    0.477679    0.454487    0.471105        -1   0.018869 -0.018869
# 1991-10-17    0.467634    0.454844    0.471523        -1  -0.021253  0.021253
# 1991-10-18    0.491071    0.455647    0.472048        -1   0.048903 -0.048903
# 1991-10-21    0.488839    0.456362    0.472561        -1  -0.004555  0.004555
# 1991-10-22    0.486607    0.456853    0.473064        -1  -0.004576  0.004576
# ...                ...         ...         ...       ...        ...       ...
# ...

# %%
data['strategy2'] = data['Position2'].shift(1) * data['returnsbh']
data
# Out:
# <ipython-input-215-8d12a29a409d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['strategy2'] = data['Position2'].shift(1) * data['returnsbh']
#                  Close       SMA_s       SMA_l  Position  returnsbh  strategy  \
# Date
# 1991-10-16    0.477679    0.454487    0.471105        -1   0.018869 -0.018869
# 1991-10-17    0.467634    0.454844    0.471523        -1  -0.021253  0.021253
# 1991-10-18    0.491071    0.455647    0.472048        -1   0.048903 -0.048903
# 1991-10-21    0.488839    0.456362    0.472561        -1  -0.004555  0.004555
# 1991-10-22    0.486607    0.456853    0.473064        -1  -0.004576  0.004576
# ...                ...         ...         ...       ...        ...       ...
# ...

# %%
data = data.dropna()
data.head()
# Out:
#                Close     SMA_s     SMA_l  Position  returnsbh  strategy  \
# Date
# 1991-10-17  0.467634  0.454844  0.471523        -1  -0.021253  0.021253
# 1991-10-18  0.491071  0.455647  0.472048        -1   0.048903 -0.048903
# 1991-10-21  0.488839  0.456362  0.472561        -1  -0.004555  0.004555
# 1991-10-22  0.486607  0.456853  0.473064        -1  -0.004576  0.004576
# 1991-10-23  0.474330  0.456786  0.473415        -1  -0.025553  0.025553
#
#             Position2  strategy2
# Date
# 1991-10-17          0       -0.0
# 1991-10-18          0        0.0
# 1991-10-21          0       -0.0
# 1991-10-22          0       -0.0
# 1991-10-23          0       -0.0

# %%
data[['returnsbh','strategy','strategy2']].sum()
# Out:
# returnsbh    6.084399
# strategy     2.752733
# strategy2    4.418566
# dtype: float64

# %%
data[['returnsbh','strategy','strategy2']].sum().apply(np.exp)  # $ 1 return
# Out:
# returnsbh    438.955839
# strategy      15.685445
# strategy2     82.977212
# dtype: float64

# %%
data[['returnsbh','strategy','strategy2']].std()*np.sqrt(252)
# Out:
# returnsbh    0.433458
# strategy     0.433584
# strategy2    0.311754
# dtype: float64

# %% [markdown]
# strategy 2 works better than both strategy 1 and returns from buy and hold, while decreasing std
